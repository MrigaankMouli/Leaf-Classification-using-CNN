# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models,layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix , classification_report
import itertools
import os
import shutil
import matplotlib.pyplot as plt

# %%
datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input,validation_split=0.3)


test_datagen = ImageDataGenerator(preprocessing_function=tf.keras.applications.vgg16.preprocess_input)

train_batches = datagen.flow_from_directory(directory="veggie_heap_training",target_size=(256,256),classes=["Apatosaur Aphie's Apples",\
                                     "Bluplocephalus Bob's Blueberries","Cherizinoasaur Cher's Cherries","Corythosaurus Cory's Corn",\
                                     "Grapthorina Greta's Grapes","Pachycephalosaurus Perry's Peaches","Pepteranodon Pep's Peppers",\
                                     "Potoceratops Pott's Potatoes","Rhaspdodon Ribery's Raspberries","Stribecosaurus Stan's Strawberries",\
                                     "Thyreosaur Tim's Thyme","vacation_photos"],batch_size=50,subset='training')
# Out:
# Found 6890 images belonging to 12 classes.

# %%
validation_batches = datagen.flow_from_directory(directory="veggie_heap_training",target_size=(256,256),classes=["Apatosaur Aphie's Apples",\
                                     "Bluplocephalus Bob's Blueberries","Cherizinoasaur Cher's Cherries","Corythosaurus Cory's Corn",\
                                     "Grapthorina Greta's Grapes","Pachycephalosaurus Perry's Peaches","Pepteranodon Pep's Peppers",\
                                     "Potoceratops Pott's Potatoes","Rhaspdodon Ribery's Raspberries","Stribecosaurus Stan's Strawberries",\
                                     "Thyreosaur Tim's Thyme","vacation_photos"],batch_size=50,subset='validation')
# Out:
# Found 2945 images belonging to 12 classes.

# %%
test_batches = test_datagen.flow_from_directory(directory="veggie_heap_testing",target_size=(256,256),classes=["Apatosaur Aphie's Apples",\
                                     "Bluplocephalus Bob's Blueberries","Cherizinoasaur Cher's Cherries","Corythosaurus Cory's Corn",\
                                     "Grapthorina Greta's Grapes","Pachycephalosaurus Perry's Peaches","Pepteranodon Pep's Peppers",\
                                     "Potoceratops Pott's Potatoes","Rhaspdodon Ribery's Raspberries","Stribecosaurus Stan's Strawberries"\
                                     ,"Thyreosaur Tim's Thyme","vacation_photos"],batch_size=1000)
# Out:
# Found 2424 images belonging to 12 classes.

# %%
images,labels = train_batches.next()

# %%
class_indices = np.argmax(labels, axis=1)

# Dictionary to store one image per class
class_images = {}

# Iterate through the batch and store one image per class
for i in range(len(class_indices)):
    class_index = class_indices[i]
    if class_index not in class_images:
        class_images[class_index] = images[i]


# Plot one image per class
num_classes = len(class_images)
fig, axes = plt.subplots(1, num_classes, figsize=(15, 10))

for i, (class_index, image) in enumerate(class_images.items()):
    axes[i].imshow(image)
    axes[i].set_title(f"Class {class_index+1}")
    axes[i].axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
CNN_Model = models.Sequential([
    layers.Conv2D(filters = 128, activation = 'relu',padding = 'same', kernel_size = (3,3), input_shape = (256,256,3)),
    layers.MaxPooling2D(pool_size = 2,strides=2,padding='same'),
    layers.Conv2D(filters = 128, activation = 'relu',padding = 'same', kernel_size = (3,3), input_shape = (256,256,3)),
    layers.MaxPooling2D(pool_size = 2,strides=2,padding='same'),
    layers.Conv2D(filters = 128, activation = 'relu',padding = 'same', kernel_size = (3,3), input_shape = (256,256,3)),
    layers.MaxPooling2D(pool_size = 2,strides=2,padding='same'),
    # dense
    layers.Flatten(),
    layers.Dense(units = 256,activation = 'relu'),
    layers.Dropout(0.4),
    layers.Dense(units = 128,activation = 'relu'),
    layers.Dropout(0.4),
    layers.Dense(units = 12, activation = 'softmax'),
])

# %%
CNN_Model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 256, 256, 128)     3584
#
#  max_pooling2d_3 (MaxPoolin  (None, 128, 128, 128)     0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 128)     147584
#
#  max_pooling2d_4 (MaxPoolin  (None, 64, 64, 128)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 131072)            0
#
#  dense_3 (Dense)             (None, 256)               33554688
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 12)                1548
#
# =================================================================
# Total params: 33887884 (129.27 MB)
# Trainable params: 33887884 (129.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
CNN_Model.compile(optimizer=Adam(learning_rate=0.001),loss = 'categorical_crossentropy',metrics = ['accuracy'])
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)

# %%
CNN_Model.fit(x=train_batches,validation_data = validation_batches,epochs=10,verbose=2,callbacks=[early_stopping])
# Out:
# Epoch 1/10
# 2024-03-30 19:46:53.817122: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1677721600 exceeds 10% of free system memory.
# 2024-03-30 19:46:57.282532: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1677721600 exceeds 10% of free system memory.
# 2024-03-30 19:46:59.431084: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1677721600 exceeds 10% of free system memory.
# 2024-03-30 19:47:02.991157: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1677721600 exceeds 10% of free system memory.
# 2024-03-30 19:47:05.131509: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 1677721600 exceeds 10% of free system memory.
#
# KeyboardInterrupt

# %%
test_images,test_labels = next(test_batches)
class_indices = np.argmax(test_labels, axis=1)

# Dictionary to store one image per class
class_images = {}

# Iterate through the batch and store one image per class
for i in range(len(class_indices)):
    class_index = class_indices[i]
    if class_index not in class_images:
        class_images[class_index] = test_images[i]


# Plot one image per class
num_classes = len(class_images)
fig, axes = plt.subplots(1, num_classes, figsize=(15, 10))

for i, (class_index, image) in enumerate(class_images.items()):
    axes[i].imshow(image)
    axes[i].set_title(f"Class {class_index+1}")
    axes[i].axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_images,test_labels = next(test_batches)
predictions = CNN_Model.predict(x=test_images,verbose=2)
loss, accuracy = CNN_Model.evaluate(test_batches)
# Out:
# 14/14 - 12s - 12s/epoch - 860ms/step
# 2024-03-30 19:51:51.430583: W tensorflow/core/framework/op_kernel.cc:1828] OP_REQUIRES failed at conv_ops_fused_impl.h:772 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1000,256,256,128] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator cpu
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[17], line 3
#       1 test_images,test_labels = next(test_batches)
#       2 predictions = CNN_Model.predict(x=test_images,verbose=2)
# ----> 3 loss, accuracy = CNN_Model.evaluate(test_batches)
#
# File ~/.local/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'sequential_1/conv2d_3/Relu' defined at (most recent call last):
#     File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 1053, in launch_instance
#       app.start()
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 195, in start
#       self.asyncio_loop.run_forever()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 529, in dispatch_queue
#       await self.process_one()
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 518, in process_one
#       await dispatch(*args)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 424, in dispatch_shell
#       await result
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 766, in execute_request
#       reply_content = await reply_content
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#       res = shell.run_cell(
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_6096/1343280793.py", line 3, in <module>
#       loss, accuracy = CNN_Model.evaluate(test_batches)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/training.py", line 2200, in evaluate
#       logs = test_function_runner.run_step(
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/training.py", line 4000, in run_step
#       tmp_logs = self._function(dataset_or_iterator)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/training.py", line 1972, in test_function
#       return step_function(self, iterator)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/training.py", line 1956, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/training.py", line 1944, in run_step
#       outputs = model.test_step(data)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/training.py", line 1850, in test_step
#       y_pred = self(x, training=False)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/training.py", line 569, in __call__
#       return super().__call__(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/sequential.py", line 405, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/functional.py", line 512, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/functional.py", line 669, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/engine/base_layer.py", line 1150, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/layers/convolutional/base_conv.py", line 321, in call
#       return self.activation(outputs)
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/activations.py", line 321, in relu
#       return backend.relu(
#     File "/home/mrigaank17/.local/lib/python3.8/site-packages/keras/src/backend.py", line 5397, in relu
#       x = tf.nn.relu(x)
# Node: 'sequential_1/conv2d_3/Relu'
# OOM when allocating tensor with shape[1000,256,256,128] and type float on /job:localhost/replica:0/task:0/device:CPU:0 by allocator cpu
# 	 [[{{node sequential_1/conv2d_3/Relu}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_test_function_2855]

# %%
predictions = np.round(predictions)
y_pred = np.argmax(predictions,axis=1)
y_true = np.argmax(test_labels,axis=1)
Labels = ["Apatosaur Aphie's Apples","Bluplocephalus Bob's Blueberries","Cherizinoasaur Cher's Cherries","Corythosaurus Cory's Corn",\
                                    "Grapthorina Greta's Grapes","Pachycephalosaurus Perry's Peaches","Pepteranodon Pep's Peppers",\
                                    "Potoceratops Pott's Potatoes","Rhaspdodon Ribery's Raspberries","Stribecosaurus Stan's Strawberries",\
                                    "Thyreosaur Tim's Thyme","vacation_photos"]

# %%
cm = confusion_matrix(y_true,y_pred)
class_report = classification_report(y_true, y_pred, target_names=Labels)

plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(Labels))
plt.xticks(tick_marks, Labels, rotation=45)
plt.yticks(tick_marks, Labels)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

print("\nClassification Report:")
print(class_report)
print(f"\nLoss = {loss}")
print(f"\nAccuracy = {accuracy*100}%")
# Out:
# /home/mrigaank17/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mrigaank17/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mrigaank17/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mrigaank17/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mrigaank17/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/mrigaank17/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Classification Report:
#                                     precision    recall  f1-score   support
#
#           Apatosaur Aphie's Apples       0.00      0.00      0.00         0
#   Bluplocephalus Bob's Blueberries       1.00      1.00      1.00         4
#     Cherizinoasaur Cher's Cherries       0.00      0.00      0.00         2
#          Corythosaurus Cory's Corn       1.00      1.00      1.00         2
#         Grapthorina Greta's Grapes       0.00      0.00      0.00         3
# Pachycephalosaurus Perry's Peaches       0.00      0.00      0.00         4
#         Pepteranodon Pep's Peppers       0.00      0.00      0.00         1
#       Potoceratops Pott's Potatoes       0.00      0.00      0.00         1
#    Rhaspdodon Ribery's Raspberries       0.00      0.00      0.00         2
# Stribecosaurus Stan's Strawberries       0.00      0.00      0.00         1
#             Thyreosaur Tim's Thyme       0.00      0.00      0.00         7
#                    vacation_photos       0.83      1.00      0.91         5
#
#                           accuracy                           0.34        32
#                          macro avg       0.24      0.25      0.24        32
#                       weighted avg       0.32      0.34      0.33        32
#
#
# Loss = 2.223764657974243
#
# Accuracy = 42.98679828643799%
